# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier

# %%
dataframe = read_csv('export_version_2_dataframe.csv')
array = dataframe.values
X = array[:,0:23]
Y = array[:,23]
# feature extraction
model = ExtraTreesClassifier(n_estimators=10)
model.fit(X, Y)
p=model.feature_importances_
p
# Out:
# array([0.03802329, 0.0429751 , 0.05462941, 0.05089015, 0.05306744,
#        0.05568013, 0.03245089, 0.03065643, 0.02981828, 0.04174763,
#        0.04628749, 0.04718945, 0.03605574, 0.05593833, 0.06277833,
#        0.02815831, 0.03095995, 0.04549454, 0.02736716, 0.01799952,
#        0.06051345, 0.05865796, 0.05266103])

# %%
import numpy as np

test = p

temp = np.argpartition(-test, 4)
result_args = temp[:10]

temp = np.partition(-test, 4)
result = -temp[:10]

# %%
import matplotlib.pyplot as plt
#features = dataframe.columns
indices = np.argsort(result)  # top 20 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), result[indices], color='b', align='center')
plt.yticks(range(len(indices)))
plt.xlabel('Relative Importance')
plt.show()

# %%
features = dataframe.columns
#importances = model.feature_importances_
p=model.feature_importances_
indices = np.argsort(p[0:20])  # top 20 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), p[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('export_version_2_dataframe.csv')
X = data.iloc[:,0:20]  #independent columns
y = data.iloc[:,-1]    #target column i.e price range
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
#print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh',align='center')
plt.title('Key Influencer')
plt.show()
# Out:
# C:\Users\Anik\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
